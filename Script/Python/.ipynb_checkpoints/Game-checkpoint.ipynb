# %%
class State():
    def __init__(self , name = "state" , sid = - 1):
        self.name = name
        self.id = sid
import random
class StateMachine():
    def __init__(self):
        self.entrystate = State()
        self.currentstate = self.entrystate
        self.states = {self.entrystate.id : self.entrystate}
        self.trsnsitions = []
        self.activedstates = []
        self.sid = self.entrystate.id
    def setcondition(self , sid):
        self.sid = sid
    def update(self):
        self.activedstates = []
        sid = self.sid
        if sid not in self.states:
            self.states[sid] = State( "state_" + sid  , sid)
        self.activedstates.append(sid)
class SMInstance():
    def __init__(self , owner):
        self.StateMachine = StateMachine()
        self.owner = owner;
        
    def update(self):
        self.StateMachine.update()
        for state in self.StateMachine.activedstates:
            self.owner.RequestManager.AddPendingRequest(state)
        pass
    def getPendingRequest(self):
        return self.StateMachine.activedstates
    pass
#this is base code
class Request():
    def __init__(self , rid = -1):
        self.rid = rid
        self.args = ""
        self.pendingargs = ""
        pass
    def setargs(self , args):
        self.pendingargs = args
    def update():
        print("Request_{0} run update with args = {1}  pending args = {2}".format(self.rid , self.args , self.pendingargs))
        
        pass
    def ApplyAction():
        
    def active():
        pass
    def unactive():
        pass
    def preupdate(self):
        pass
    pass
class Action():
    def __init__(self):
        pass
    def 
    pass
class RequestManager():
    def __init__(self):
        self.RequestMap = {}
        self.RunningRequestMap = {}
        self.PendingRequestMap = {}
        pass
    def GetRequest(self , requestid):
        if requestId not in self.RequestMap:
            # 反射创建类对象
            self.RequestMap[requestid] = Request(requestid)
        return self.RequestMap[requestid]
    def AddPendingRequest(self , requestId):
        self.RequestMap[requestId] = true
        self.PendingRequestMap[requestId] = true
        pass
    def FlipRequest():
        pass
    def update(self):
        # Running = 1 , 3 , 4
        # Pending = 2 , 4 , 6
        # pending -> Running ?
        pass
    pass

class Actor():
    def DoStrageri(self):
        
        pass
    def DoRequest(self):
        pass
    def DoAction(self):
        pass
    def DoAnim(self):
        pass
    pass
